# %%
#importação de bibliotecas
import nltk
import urllib
import bs4 as bs
import re 
from gensim.models  import Word2Vec
import pandas as pd
import numpy as np

# %%
#download nltk

nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopword')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Error loading stopword: Package 'stopword' not found in
# [nltk_data]     index
# False

# %%
#importar base de dados 

comentarios = pd.read_csv("https://raw.githubusercontent.com/franciscofabio/Cluster_texto_NLTK/main/magalu3_2022_n/tweets.csv", delimiter = ",", encoding='UTF-8')

# %%
comentarios['tweet']
# Out:
# 0       harry ta trabalhando no magazine luiza? nao? M...
# 1       Achei a dita vasilha do Spoleto no @magazinelu...
# 2       Sofá Retrátil Reclinável 3 Lugares Velosuede L...
# 3       O que rolou aqui magalu??? querendo me vender ...
# 4       🚨Oferta Magazine Luiza   🛍 La Roche Posay Effa...
#                               ...
# 2290    @magazineluiza @lerreg Ue na adm? Nós também q...
# 2291    Amiga @magazineluiza , me ajuda a ver #pantana...
# 2292    @jhopxart @caioluzgomes @lydiabrasil @obrigahi...
# 2293            @colaressluisa @magazineluiza Véi eu JURO
# 2294    O presidente da Multilaser, em um video no per...
# Name: tweet, Length: 2295, dtype: object

# %%
comentarios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2295 entries, 0 to 2294
# Data columns (total 36 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               2295 non-null   int64
#  1   conversation_id  2295 non-null   int64
#  2   created_at       2295 non-null   object
#  3   date             2295 non-null   object
#  4   time             2295 non-null   object
#  5   timezone         2295 non-null   int64
#  6   user_id          2295 non-null   int64
#  7   username         2295 non-null   object
#  8   name             2295 non-null   object
#  9   place            3 non-null      object
#  10  tweet            2295 non-null   object
#  11  language         2295 non-null   object
#  12  mentions         2295 non-null   object
#  13  urls             2295 non-null   object
#  14  photos           2295 non-null   object
#  15  replies_count    2295 non-null   int64
#  16  retweets_count   2295 non-null   int64
#  17  likes_count      2295 non-null   int64
#  18  hashtags         2295 non-null   object
#  19  cashtags         2295 non-null   object
#  20  link             2295 non-null   object
#  21  retweet          2295 non-null   bool
#  22  quote_url        72 non-null     object
#  23  video            2295 non-null   int64
#  24  thumbnail        254 non-null    object
#  25  near             0 non-null      float64
#  26  geo              0 non-null      float64
#  27  source           0 non-null      float64
#  28  user_rt_id       0 non-null      float64
#  29  user_rt          0 non-null      float64
#  30  retweet_id       0 non-null      float64
#  31  reply_to         2295 non-null   object
#  32  retweet_date     0 non-null      float64
#  33  translate        0 non-null      float64
#  34  trans_src        0 non-null      float64
#  35  trans_dest       0 non-null      float64
# dtypes: bool(1), float64(10), int64(8), object(17)
# memory usage: 629.9+ KB

# %%
nltk.download("webtext")
# Out:
# [nltk_data] Downloading package webtext to /root/nltk_data...
# [nltk_data]   Package webtext is already up-to-date!
# True

# %%
#transformar a coluna manifestação em uma lista 

col_one_list = comentarios['tweet'].tolist()
texto = str(col_one_list)

# %%
texto
# Out:
# '[\'harry ta trabalhando no magazine luiza? nao? Mas e esses coxão aqui?  https://t.co/7cU70jrJUr\', \'Achei a dita vasilha do Spoleto no @magazineluiza. Tudo na minha carreira.  https://t.co/xyRscNc5Gg\', \'Sofá Retrátil Reclinável 3 Lugares Velosuede Lazio - Next Sofás (cód. magazineluiza 227262100) Cor: Creme Vendido e entregue por Magalu de   R$ 1.999,00 por R$ 1.234,05 à vista (5% Desc. já calculado.) ou R$ 1.299,00 em 10x de R$ 129,90 sem juros Comprar:  https://t.co/WUukGrKeh1  https://t.co/tD68Pi6Zun\', \'O que rolou aqui magalu??? querendo me vender maconha pela internet, olha só! e não é meme de primeiro de abril não @magazineluiza  https://t.co/rBbuENJG91\', \'🚨Oferta Magazine Luiza   🛍 La Roche Posay Effaclar Kit - Gel Concentrado 📌 O Kit Contém: 2 La Roche Posay Effaclar Gel Concentrado - 300g  💵R$ 119,80 📦FRETE GRÁTIS  🛒  https://t.co/aEmL68gW7Q  https://t.co/O3vrkxujzx\', \'@Belga_briel @magazineluiza imperdivel, ja garanti o meu\', \'🚨Oferta Magazine Luiza   🛍 Vichy Dercos Energizante Kit - Shampoo + Shampoo Refil 💵R$ 157,00 📦FRETE GRÁTIS  🛒  https://t.co/H345OsYtyY  https://t.co/8UDVhYY59j\', \'🚨Oferta Magazine Luiza   🛍 Cadeira Gamer XT Racer Reclinável Preta e Cinza 💵R$ 949,90 🛒  https://t.co/FPwhpd5OcX  https://t.co/Comd9xAqeU\', \'@magazineluiza @PasswordBig @Anitta 😍\', \'@magazineluiza amiga quero comprar um microondas me dá ai um cupom de desconto\', \'@magazineluiza @Anitta Ameii\', \'🚨Oferta Magazine Luiza   🛍 Jogo de Taças de Vidro 330ml 6 Peças Haus 💵R$ 69,90 🛒  https://t.co/4Lmcn93ZFa  https://t.co/59aRdR9Cbi\', \'MGLU3 - AÇÕES MAGAZINE LUIZA BOMBANDO HOJE OU TAMBÉM HOJE?   AQUI ANÁLIS...  https://t.co/pQxvpFL478 via @YouTube  Pooooowwww!!!! #mglu3 #magalu #magazineluiza #analisetecnica #swingtrade #bolsadevalores  https://t.co/26zdBVf19f\', \'Poxa @magazineluiza para de aumentar o preço do iPhone porque to tentando me programar pra comprar 🤡 Ajuda a jovem empreendedora kkkk\', \'#magalu @magazineluiza que falta de respeito... fiz uma compra e até agora não recebi, solicitei o extorno mas não me atenderão até o presente momento... @proconspoficial #proconsp  https://t.co/tUO7SNlMTv\', \'magazine Luiza é podre, vai se FODER, terceiro prazo que eles colocam p entregar esse crlh e não chega, que nojo dessa empresa fudida\', \'@amotartaruga @pabloo_muller @marcusbarbosaaa @gaybrielsz @neymarjr @Cristiano @CopadoBrasil @Mundocopaa @BoleirosOusados @cbjroficial Vc marcou a magazine luiza, seu noia\', \'@paolamello_ @magazineluiza chamaram na dm pra nada mesmo so pra quem ta vendo ficar com a impressão de que eles resolvem algum problema e passar uma imagem de que são preocupado com clientes mas a realidade noiz sabe como que funciona\', \'Du nada magazine luiza vendendo maconha e balaclava skskskskks  https://t.co/a0pMOFuSGI\', \'@BigBossBBB22 @ohayzinhoo @siteptbr Não. Pensei que eram da Rede Magazine Luiza.\', \'@CarolMotta_76 @AliExpressBR @magazineluiza @MercadoLivre Baratinha não tá bancando nem saia de filó, quem dirá essas dai 😆😆😆\', \'@peuzao1 @magazineluiza ? 🤨\', \'Que isso @magazineluiza ?  https://t.co/Ltix3Xd03n\', \'@magazineluiza @djduhfranca chamar na DM e não resolver nada não adianta social media da Magalu 🤡 vê se pelo menos RESOLVE\', \'[Magazine Luiza] Conjunto de Mesa com 4 Cadeiras Estofadas - Viero Móveis Valência R$ 1614,00 #desconto #oferta #promocao #conjunto  https://t.co/fBgGx8kgsq\', \'Ando tão pra baixo, até o magazine Luiza me inativou no app\', \'alguém teria um celular parado ai pra me emprestar, ja que a dona @magazineluiza nao entrega o que promete e ainda enrola pra liberar o limite que é meu pra que possa fazer minha compra 30 dias pra um cancelamento é muita patifaria se tiver contato de um advogado também liga noiz\', \'ai vou eu tentar fazer o cancelamento da compra, so vai cancelar semana que vem e so vai liberar meu limite daqui 30 dias  vai tomar no @magazineluiza  nunca senti tanto ódio de uma empresa como eu to sentindo @luizatrajano o processo vem pode espera ...

# %%
#converter lista para texto 
moby_tokens = nltk.word_tokenize(texto)
text1 = nltk.Text(moby_tokens)
text1
# Out:
# <Text: [ 'harry ta trabalhando no magazine luiza ?...>

# %%
#total de termos no documento
from nltk.stem import WordNetLemmatizer

def total_termos():

    lemmatizer = WordNetLemmatizer()
    lemmatized = [lemmatizer.lemmatize(w,'v') for w in text1]

    return len(set(lemmatized))

total_termos()
# Out:
# 8947

# %%
#importar bibliotecas bigram 
from nltk.collocations import BigramCollocationFinder
from nltk.metrics import BigramAssocMeasures
from nltk.corpus import stopwords

# %%
#encontrar bigrams por token 

procurar = BigramCollocationFinder.from_words(moby_tokens)

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
#retira stopwords
retira = set(stopwords.words('portuguese'))

# %%
filtra = lambda w: len(w) <3 or w in retira

# %%
procurar.apply_word_filter(filtra)

# %%
#bigram 
procurar.nbest(BigramAssocMeasures.likelihood_ratio, 60)
# Out:
# [('Magazine', 'Luiza'),
#  ('magazine', 'luiza'),
#  ('magazine', 'Luiza'),
#  ('Nova', 'Geração'),
#  ('2020', 'Nova'),
#  ("'🚨Oferta", 'Magazine'),
#  ('algumas', 'regiões'),
#  ('MAGAZINE', 'LUIZA'),
#  ("'Magazine", 'Luiza'),
#  ('📦FRETE', 'GRÁTIS'),
#  ('Gabriel', 'Monteiro'),
#  ('Controle', 'Branco'),
#  ('Branco', 'Sony'),
#  ('Geração', '825GB'),
#  ('1TB', 'SSD'),
#  ('Xbox', 'Series'),
#  ('Geração', '1TB'),
#  ('frete', 'grátis'),
#  ('pra', 'mim'),
#  ('São', 'Paulo'),
#  ('nota', 'fiscal'),
#  ('Aragão', 'Pinterest'),
#  ('Força', 'Gio'),
#  ('Gio', 'Renato'),
#  ('Pinterest', 'Pfizer'),
#  ('Renato', 'Aragão'),
#  ('Controle', 'Preto'),
#  ("'Xbox", 'Series'),
#  ('Bom', 'dia'),
#  ('Preto', 'Microsoft'),
#  ('época', 'cosméticos'),
#  ('tudo', 'bem'),
#  ("'magazine", 'luiza'),
#  ("'EBS", 'Propaganda'),
#  ('documentos', 'referentes'),
#  ('criança', 'vulnerável'),
#  ('Digital', 'Edition'),
#  ('alguma', 'coisa'),
#  ('GRÁTIS', '📌Vendido'),
#  ('dias', 'úteis'),
#  ('⭐⭐⭐⭐⭐', 'Menor'),
#  ('magazineluiza', 'Compraria'),
#  ('Menor', 'preço'),
#  ('Edition', '2020'),
#  ("'⚠️", 'Alerta'),
#  ('diz', 'CEO'),
#  ('vai', 'ser'),
#  ('Compra', 'Junto'),
#  ('promocao', 'https'),
#  ('pra', 'ver'),
#  ('09:33', 'disse'),
#  ('parcelas', '⭐⭐⭐⭐⭐'),
#  ('Loja', 'parceira'),
#  ('Anitta', 'Gostosa'),
#  ('pra', 'comprar'),
#  ('Quem', 'lacra'),
#  ('e-mail', 'dizendo'),
#  ('jeito', 'nenhum'),
#  ('The', 'Walking'),
#  ('Walking', 'Dead')]

# %%
#quais são os termos mais frequentes 
def termos_frequentes():
  dist = nltk.FreqDist(text1)
  vocab1= dist.keys()
  freqwords = [w for w in vocab1 if len(w) > 3 and dist[w] >2]
  return sorted(freqwords)
termos_frequentes()
# Out:
# ["'Acabou",
#  "'Box",
#  "'Como",
#  "'Comprei",
#  "'Descontos",
#  "'EBS",
#  "'Esse",
#  "'Fiz",
#  "'Gente",
#  "'Kit",
#  "'MagaluPay",
#  "'Magazine",
#  "'Meu",
#  "'Nossa",
#  "'Nunca",
#  "'Não",
#  "'Ola",
#  "'PS5",
#  "'Pelo",
#  "'PlayStation",
#  "'Poxa",
#  "'Que",
#  "'Queda",
#  "'Tem",
#  "'Xbox",
#  "'alô",
#  "'comprei",
#  "'gente",
#  "'magazine",
#  "'meu",
#  "'nossa",
#  "'não",
#  "'que",
#  "'🚨Oferta",
#  '//t.co/0ckNslhMYl',
#  '//t.co/8vrFpgBrNq',
#  '//t.co/VEK17OKO9X',
#  '//t.co/w4DQWn8rwQ',
#  '//t.co/ycTuk9SFle',
#  '0800',
#  '08bits',
#  '09:33',
#  '2020',
#  '2022',
#  '28.3',
#  '287,88',
#  '59,90',
#  '69,90',
#  '825GB',
#  '911Literatura',
#  'AGORA',
#  'AMER3',
#  'AQUI',
#  'Acabei',
#  'Acho',
#  'Acreditamos',
#  'Acredito',
#  'Agora',
#  'Ainda',
#  'Ajuda',
#  'Alerta',
#  'Alguém',
#  'Amazon',
#  'Americanas',
#  'Anitta',
#  'Apesar',
#  'Aqui',
#  'Aragão',
#  'Assim',
#  'Açaí',
#  'BRAP4',
#  'Bandido',
#  'Black',
#  'BoleirosOusados',
#  'Bolsonaro',
#  'Bonecos',
#  'Bora',
#  'Bradespar',
#  'Branco',
#  'Brasil',
#  'BuserBrasil',
#  'COMPRA',
#  'COMPRAR',
#  'CYRE3',
#  'Cadeira',
#  'Cadê',
#  'Cama',
#  'CarlosLealTech',
#  'CasasBahia',
#  'Caso',
#  'Cinza',
#  'Colecionáveis',
#  'Coloquei',
#  'Como',
#  'Compra',
#  'Comprar',
#  'Compraria',
#  'Compre',
#  'Comprei',
#  'Condicionador',
#  'Confira',
#  'Conservadora191',
#  'Controle',
#  'CopadoBrasil',
#  'Correios',
#  'CorreiosBR',
#  'Creme',
#  'Cristiano',
#  'Cupom',
#  'CupomDeDesconto',
#  'Cyrela',
#  'Dead',
#  'DellnoBrasil',
#  'Depois',
#  'Dercos',
#  'Desde',
#  'DesmonetizaGabrielMonteiro',
#  'Deus',
#  'Digital',
#  'Disponível',
#  'Dona',
#  'Douglas86736732',
#  'Edition',
#  'Eduardo',
#  'Eita',
#  'Eles',
#  'Empresas',
#  'Enquanto',
#  'Entrega',
#  'Então',
#  'Envia',
#  'Esportivo',
#  'Essa',
#  'Esse',
#  'Estou',
#  'Está',
#  'Estão',
#  'Feminino',
#  'FiatBR',
#  'Fora',
#  'Força',
#  'GRÁTIS',
#  'Gabriel',
#  'Galaxy',
#  'Gamer',
#  'Gavetas',
#  'Geração',
#  'Globo',
#  'GordoGeek',
#  'Gostaria',
#  'Gostosa',
#  'Havan',
#  'Hoje',
#  'IamKlimarx',
#  'Inclusive',
#  'Informamos',
#  'Investiria',
#  'Isso',
#  'Itaú',
#  'Jesus',
#  'Jogo',
#  'JornalOGlobo',
#  'Jovem',
#  'Junto',
#  'KKKKKKKK',
#  'KKKKKKKKKKK',
#  'Kabum',
#  'King',
#  'Kkkk',
#  'Kkkkk',
#  'Kkkkkkkkk',
#  'LOJAS',
#  'LUIZA',
#  'Legal',
#  'Libera',
#  'Linda',
#  'Liquidações',
#  'Livro',
#  'Loja',
#  'LucianoHangBr',
#  'Lugares',
#  'Luiza',
#  'Luiza-Magalu',
#  'Lula',
#  'LulaOficial',
#  'Luíza',
#  'MAGALU',
#  'MAGAZINE',
#  'MAIS',
#  'MGLU3',
#  'MINHA',
#  'MUITO',
#  'Maga',
#  'Magalu',
#  'Magaly',
#  'Magazine',
#  'MagazineLuiza',
#  'Magazineluiza',
#  'Mais',
#  'Manda',
#  'March',
#  'Marketing',
#  'Masculina',
#  'Masculino',
#  'Mediana',
#  'Melhor',
#  'MeliuzOficial',
#  'Menor',
#  'MercadoLivre',
#  'Mesa',
#  'Microsoft',
#  'Minha',
#  'Miniaturas',
#  'Misericórdia',
#  'MmendesjrA',
#  'Monitor',
#  'Monteiro',
#  'Muito',
#  'Multilaser',
#  'Multilaser_BR',
#  'Mundocopaa',
#  'Máscara',
#  'Méliuz',
#  'NADA',
#  'NOVO',
#  'NUNCA',
#  'Nada',
#  'Napolitano',
#  'Natura',
#  'Nell',
#  'Netshoes',
#  'Nossa',
#  'Nova',
#  'Nunca',
#  'OTechnoLeo',
#  'Oakley',
#  'Obrigada',
#  'Obrigado',
#  'Oferta',
#  'Online',
#  'PORRA',
#  'PRECISO',
#  'Para',
#  'Parabéns',
#  'Parece',
#  'Paulo',
#  'Pedimos',
#  'Pelo',
#  'Pena',
#  'Pensei',
#  'Peças',
#  'Pfizer',
#  'Pinheiros',
#  'Pinterest',
#  'Pior',
#  'PlayStation',
#  'PlayStation5',
#  'Pode',
#  'Poderia',
#  'Pois',
#  'Pokebolas',
#  'Pokemons',
#  'Positivo',
#  'Poxa',
#  'Preciso',
#  'Preta',
#  'Preto',
#  'Primeiro',
#  'Processo',
#  'Procon',
#  'Promoção',
#  'Propaganda',
#  'Qual',
#  'Quando',
#  'Quem',
#  'Quer',
#  'Queria',
#  'Quero',
#  'Racer',
#  'ReclameAQUI',
#  'Reclinável',
#  'RedDrigo',
#  'Renato',
#  'Respondi',
#  'Retornou',
#  'Retrátil',
#  'Saiba',
#  'Samsung',
#  'SamsungBrasil',
#  'Segundo',
#  'Sempre',
#  'Seria',
#  'Series',
#  'Será',
#  'Shampoo',
#  'Shopee',
#  'Sleeping',
#  'Smartphone',
#  'SmilesOficial',
#  'Socorro',
#  'Sono',
#  'Sony',
#  'SuzyPecas',
#  'Sério',
#  'TIMBrasil',
#  'TODAS',
#  'Também',
#  'Tatymorais03',
#  'Taças',
#  'Tec_Mundo',
#  'Tenho',
#  'Todos',
#  'Trajano',
#  'Triste',
#  'Tudo',
#  'Twitter',
#  'Tênis',
#  'Unidades',
#  'VIIA3',
#  'Vamos',
#  'Veja',
#  'Vendido',
#  'Vichy',
#  'Vidro',
#  'Você',
#  'Vocês',
#  'Walking',
#  'Wella',
#  'Xbox',
#  'YouTube',
#  'YouTubeBrasil',
#  '\\U0001f972',
#  '\\xa0',
#  '\\xa03.999,90',
#  '\\xa0399,99',
#  '\\xa04.499,99',
#  '\\xa04.999,99',
#  '\\xa0450,00',
#  '\\xa0500,00',
#  '_Andynee',
#  'aberta',
#  'aberto',
#  'abre',
#  'abril',
#  'abrir',
#  'abriu',
#  'absurdo',
#  'acaba',
#  'acabar',
#  'acabou',
#  'acessar',
#  'acesse',
#  'acha',
#  'acham',
#  'achar',
#  'achei',
#  'acho',
#  'acima',
#  'acontece',
#  'acontecendo',
#  'acontecer',
#  'aconteceu',
#  'acredito',
#  'adianta',
#  'adidasbrasil',
#  'advogado',
#  'agora',
#  'aguardando',
#  'aguardar',
#  'aguarde',
#  'aguardo',
#  'agência',
#  'ainda',
#  'ajuda',
#  'ajudar',
#  'ajudaria',
#  'ajudem',
#  'algo',
#  'algum',
#  'alguma',
#  'algumas',
#  'alguns',
#  'alguém',
#  'alta',
#  'altas',
#  'alto',
#  'alugar',
#  'aluguel',
#  'alvo',
#  'além',
#  'amanhã',
#  'amazing',
#  'amazonBR',
#  'amei',
#  'americanas',
#  'amiga',
#  'amigo',
#  'amigos',
#  'amor',
#  'amotartaruga',
#  'anaexmachina',
#  'aniversário',
#  'anos',
#  'ansiedade',
#  'anterior',
#  'antes',
#  'antigo',
#  'anuidade',
#  'análise',
#  'apareceu',
#  'apenas',
#  'aplicativo',
#  'apoia',
#  'apoiar',
#  'apoio',
#  'aprovado',
#  'aprovar',
#  'após',
#  'aquela',
#  'aquele',
#  'aqueles',
#  'aqui',
#  'artigo',
#  'assalariado',
#  'assim',
#  'atende',
#  'atendente',
#  'atendida',
#  'atendimento',
#  'atraso',
#  'através',
#  'atrás',
#  'atual',
#  'atualizado',
#  'atualização',
#  'aumentar',
#  'autorizar',
#  'avatar',
#  'azaghal',
#  'ação',
#  'ações',
#  'baixa',
#  'baixas',
#  'baixinha',
#  'bandido',
#  'bando',
#  'baratinho',
#  'barato',
#  'barra',
#  'barraco',
#  'bastante',
#  'beingtheJr',
#  'berço',
#  'bloqueado',
#  'boas',
#  'boleto',
#  'bolsa',
#  'boneca',
#  'bonita',
#  'bosta',
#  'bota',
#  'botar',
#  'br_heinz',
#  'brancos',
#  'brasileiro',
#  'brastemp',
#  'braço',
#  'brunoi90',
#  'buagin',
#  'buscar',
#  'cabeça',
#  'cada',
#  'cadastro',
#  'cadeira',
#  'cadê',
#  'caem',
#  'caiu',
#  'caixa',
#  'cama',
#  'campanha',
#  'canais',
#  'canal',
#  'cancelado',
#  'cancelamento',
#  'cancelar',
#  'cancelaram',
#  'capa',
#  'cara',
#  'caracteriza-se',
#  'caralho',
#  'caras',
#  'caro',
#  'caros',
#  'carrinho',
#  'carro',
#  'cartao',
#  'carteira',
#  'cartão',
#  'cartões',
#  'casa',
#  'casamento',
#  'cashback',
#  'caso',
#  'categoria',
#  'causa',
#  'celular',
#  'centenas',
#  'centro',
#  'certeza',
#  'certinho',
#  'certo',
#  'chama',
#  'chamar',
#  'chat',
#  'chega',
#  'chegando',
#  'chegar',
#  'chegou',
#  'cheguei',
#  'cheio',
#  'chicoboldrini',
#  'chorar',
#  'cidade',
#  'cidadão',
#  'cima',
#  'circo',
#  'claro',
#  'cliente',
#  'clientes',
#  'cobrando',
#  'coisa',
#  'coisas',
#  'coleta',
#  'colocando',
#  'colocar',
#  'colocaram',
#  'coloquei',
#  'começar',
#  'comigo',
#  'como',
#  'compactua',
#  'completamente',
#  'completar',
#  'compra',
#  'comprado',
#  'compramos',
#  'comprando',
#  'comprar',
#  'compraria',
#  'compras',
#  'compre',
#  'comprei',
#  'comprem',
#  'compro',
#  'compromissos',
#  'comprou',
#  'computador',
#  'concorrência',
#  'condições',
#  'conduta',
#  'confia',
#  'confira',
#  'confirmar',
#  'confirmação',
#  'conforme',
#  'conhecer',
#  'conquistado',
#  'consegui',
#  'conseguindo',
#  'conseguir',
#  'conseguiu',
#  'consigo',
#  'consumidor',
#  'consumidores',
#  'conta',
#  'contando',
#  'contar',
#  'contato',
#  'conteúdo',
#  'continuar',
#  'conto',
#  'contra',
#  'controle',
#  'coração',
#  'corre',
#  'cortar',
#  'cosméticos',
#  'cozinha',
#  'criança',
#  'crianças',
#  'criar',
#  'crime',
#  'criminoso',
#  'cropped',
#  'crédito',
#  'culpa',
#  'cumprir',
#  'cupom',
#  'cupons',
#  'cuponzinho',
#  'código',
#  'dado',
#  'dados',
#  'dando',
#  'daqui',
#  'dariopessoaj',
#  'data',
#  'david_agape_',
#  'deboche',
#  'decepção',
#  'defeito',
#  'defender',
#  'deixa',
#  'deixar',
#  'deixou',
#  'dela',
#  'dele',
#  'deles',
#  'demais',
#  'demora',
#  'demoram',
#  'demorando',
#  'demorar',
#  'dentro',
#  'depois',
#  'deram',
#  'descaso',
#  'desconto',
#  'descumprimento',
#  'desde',
#  'desliga',
#  'desmonetizar',
#  'dessa',
#  'desse',
#  'desta',
#  'destaque',
#  'deste',
#  'deus',
#  'deve',
#  'deveria',
#  'devia',
#  'devolver',
#  'diariamente',
#  'dias',
#  'diferente',
#  'difícil',
#  'digital',
#  'digitalize',
#  'dinheiro',
#  'direto',
#  'dispararam',
#  'disponível',
#  'disse',
#  'disseram',
#  'disso',
#  'distribuição',
#  'dividir',
#  'dizem',
#  'dizendo',
#  'dizer',
#  'documentos',
#  'dois',
#  'dona',
#  'dono',
#  'dormindo',
#  'dormir',
#  'duas',
#  'dólar',
#  'dúvida',
#  'e-mail',
#  'educação',
#  'efetuar',
#  'eibalvetti',
#  'elcumba',
#  'eles',
#  'eletrodomésticos',
#  'email',
#  'empresa',
#  'empresas',
#  'empresários',
#  'encomenda',
#  'endereço',
#  'enquanto',
#  'enrolam',
#  'enrolando',
#  'entender',
#  'entrar',
#  'entre',
#  'entrega',
#  'entregador',
#  'entregam',
#  'entregar',
#  'entregaram',
#  'entregas',
#  'entregou',
#  'entregue',
#  'entrei',
#  'entro',
#  'então',
#  'envia',
#  'enviado',
#  'enviar',
#  'enviaram',
#  'enviei',
#  'envolver',
#  'eram',
#  'errada',
#  'errado',
#  'erro',
#  'escolher',
#  'espera',
#  'esperando',
#  'esperar',
#  'espero',
#  'esposa',
#  'esquece',
#  'esqueci',
#  'esquema',
#  'esquerdista',
#  'essa',
#  'essas',
#  'esse',
#  'esses',
#  'esta',
#  'estado',
#  'estamos',
#  'estar',
#  'estaria',
#  'estava',
#  'este',
#  'estoque',
#  'estorno',
#  'estou',
#  'estresse',
#  'está',
#  'estão',
#  'exatamente',
#  'excelente',
#  'exemplo',
#  'existe',
#  'experiência',
#  'explica',
#  'explora',
#  'exploração',
#  'extra',
#  'fabioteles007',
#  'fake',
#  'fala',
#  'falam',
#  'falando',
#  'falar',
#  'falaram',
#  'falei',
#  'falha',
#  'falou',
#  'falso',
#  'falta',
#  'familiaextra',
#  'família',
#  'faria',
#  'fastshop',
#  'fato',
#  'fatura',
#  'favor',
#  'fazem',
#  'fazendo',
#  'fazer',
#  'faça',
#  'faço',
#  'fechada',
#  'fechar',
#  'feira',
#  'feita',
#  'feito',
#  'felipeneto',
#  'feliz',
#  'ferrar',
#  'fica',
#  'ficam',
#  'ficar',
#  'ficava',
#  'fico',
#  'ficou',
#  'fila',
#  'filha',
#  'filme',
#  'filtro',
#  'final',
#  'fiquei',
#  'fiscal',
#  'fizeram',
#  'fizesse',
#  'foda',
#  'foder',
#  'fogão',
#  'fora',
#  'foram',
#  'forma',
#  'fornecedor',
#  'força',
#  'fosse',
#  'foto',
#  'fotos',
#  'frente',
#  'frete',
#  'frio',
#  'fuder',
#  'funciona',
#  'funcionando',
#  'funcionários',
#  'fábrica',
#  'fácil',
#  'física',
#  'físicas',
#  'galera',
#  'games',
#  'ganha',
#  'ganhar',
#  'ganhei',
#  'ganho',
#  'garantia',
#  'gastando',
#  'gata',
#  'gaybrielsz',
#  'geladeira',
#  'gente',
#  'gerente',
#  'gestão',
#  'giants',
#  'golpe',
#  'gostaria',
#  'gosto',
#  'gostosa',
#  'governo',
#  'grana',
#  'grande',
#  'grandes',
#  'graça',
#  'grupo',
#  'grátis',
#  'guitoalari',
#  'hahaha',
#  'havanoficial',
#  'hein',
#  'hipocrisia',
#  'história',
#  'hoje',
#  'hora',
#  'horas',
#  'horrores',
#  'horrível',
#  'horário',
#  'houve',
#  'https',
#  'iPhone',
#  'ideia',
#  'idiotas',
#  'igual',
#  'imagem',
#  'imagina',
#  'impossível',
#  'inclusive',
#  'incríveis',
#  'infelizmente',
#  'informar',
#  'informações',
#  'integra',
#  'internet',
#  'investimentos',
#  'investiria',
#  'início',
#  'iphone',
#  'iria',
#  'irmão',
#  'isso',
#  'itau',
#  'itens',
#  'jameson_costa_',
#  'jeito',
#  'jklimaitis',
#  'joaogomeseu',
#  'jogando',
#  'jogar',
#  'jogo',
#  'josuelsantosbch',
#  'jovemnerd',
#  'junto',
#  'juros',
#  'justiça',
#  'kabumcombr',
#  'kakakaka',
#  'katyperry',
#  'kkkk',
#  'kkkkk',
#  'kkkkkk',
#  'kkkkkkk',
#  'kkkkkkkk',
#  'kkkkkkkkk',
#  'lacra',
#  'lacrar',
#  'lado',
#  'lança',
#  'lava',
#  'lavar',
#  'legal',
#  'leiamoneytimes',
#  'leleo6627',
#  'lembra',
#  'lembrando',
#  'lerreg',
#  'leva',
#  'libera',
#  'liberar',
#  'lidar',
#  'liga',
#  'ligação',
#  'ligações',
#  'liguei',
#  'like',
#  'limite',
#  'linda',
#  'linha',
#  'link',
#  'lista',
#  'livro',
#  'lixo',
#  'logar',
#  'logo',
#  'loiro_josee',
#  'loja',
#  'lojas',
#  'longe',
#  'lote',
#  'lucra',
#  'lugar',
#  'luiza',
#  'luizatrajano',
#  'luizpitu2',
#  'luvisetto_',
#  'macetava',
#  'maconha',
#  'magalu',
#  'magazine',
#  'magazineluiza',
#  'maior',
#  'maiores',
#  'mais',
#  'maluco',
#  'manda',
#  'mandam',
#  'mandar',
#  'mandaram',
#  'mandei',
#  'mandou',
#  'manha',
#  'manhã',
#  'mano',
#  'mantém',
#  'marca',
#  'marketplace',
#  'março',
#  'massa',
#  'meio',
#  'melhor',
#  'melhorar',
#  'melhores',
#  'meme',
#  'menina',
#  'menor',
#  'menos',
#  'mensagem',
#  'mensagens',
#  'mentir',
#  'mentira',
#  'mercado',
#  'mercadofinanceiro',
#  'mercadorias',
#  'merda',
#  'merece',
#  'meses',
#  'mesma',
#  'mesmo',
#  'meteu',
#  'meus',
#  'microondas',
#  'milhões',
#  'minha',
#  'minhas',
#  'minutos',
#  'momento',
#  'monitor',
#  'mora',
#  'moral',
#  'moro',
#  'mostrando',
#  'motivo',
#  'mudaram',
#  'muita',
#  'muito',
#  'mulher',
#  ...]

# %%
dist = nltk.FreqDist(text1)
vocab1 = dist.keys()
freqwords = [w for w in vocab1 if len(w) > 3 and dist[w] >2]
total = str(freqwords)

# %%
#wordcloud 
from wordcloud import WordCloud
import matplotlib.pyplot as plt

wordcloud = WordCloud(max_font_size=100, width=1520, height=535).generate(total)
plt.figure(figsize=(16,9))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %% [markdown]
# Cluster

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import normalize
from sklearn.cluster import KMeans
from sklearn.metrics.pairwise import cosine_similarity

# %%
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(comentarios["tweet"])

# %%
X = normalize(X)

# %%
kmeans = KMeans(
    n_clusters=8,
    n_init=15,
    max_iter=450,
    init = 'k-means++'
    


)

# %%
#treinar 

kmeans.fit(X)
# Out:
# KMeans(max_iter=450, n_init=15)

# %%
comentarios['cluster'] = kmeans.labels_
comentarios
# Out:
#                        id      conversation_id               created_at  \
# 0     1510044210057121795  1510044210057121795  2022-04-01 23:59:29 UTC
# 1     1510042720789843984  1510042720789843984  2022-04-01 23:53:34 UTC
# 2     1510042466220752903  1510042466220752903  2022-04-01 23:52:33 UTC
# 3     1510042402710511619  1510042402710511619  2022-04-01 23:52:18 UTC
# 4     1510041539711582213  1510041539711582213  2022-04-01 23:48:52 UTC
# ...                   ...                  ...                      ...
# 2290  1507562359824568320  1507536292434923525  2022-03-26 03:37:30 UTC
# 2291  1507559336888971265  1507559336888971265  2022-03-26 03:25:29 UTC
# 2292  1507559315531603973  1507434468688203777  2022-03-26 03:25:24 UTC
# 2293  1507559160665280512  1507431486894616585  2022-03-26 03:24:47 UTC
# 2294  1507557747700686852  1507557747700686852  2022-03-26 03:19:10 UTC
#
#             date      time  timezone              user_id         username  \
# 0     2022-04-01  23:59:29         0            334342957         saynarry
# 1     2022-04-01  23:53:34         0             78776350     tiathaicomth
# 2     2022-04-01  23:52:33         0   915672772269002752      brotherjp21
# 3     2022-04-01  23:52:18         0           2686051339  higorfmarcelino
# 4     2022-04-01  23:48:52         0  1496075113577467904  achadoscompromo
# ...          ...       ...       ...                  ...              ...
# 2290  2022-03-26  03:37:30         0            130806497       artluciano
# 2291  2022-03-26  03:25:29         0             33516608    alex_jr_faoro
# 2292  2022-03-26  03:25:24         0  1110704838772510720      oldmanharri
# 2293  2022-03-26  03:24:47         0            478180447     luhvalente__
# 2294  2022-03-26  03:19:10         0            291782375  marcusmarverick
#
#                           name place  ... source user_rt_id user_rt  \
# 0            lau • 56d to LTWT   NaN  ...    NaN        NaN     NaN
# 1     in adaptation period 🦁🧡🥊   NaN  ...    NaN        NaN     NaN
# 2                    JP CUPOM%   NaN  ...    NaN        NaN     NaN
# 3                        higão   NaN  ...    NaN        NaN     NaN
# 4                     Promoção   NaN  ...    NaN        NaN     NaN
# ...                        ...   ...  ...    ...        ...     ...
# 2290        luciano dos santos   NaN  ...    NaN        NaN     NaN
# 2291                 Alexandro   NaN  ...    NaN        NaN     NaN
# 2292             Old Man Harri   NaN  ...    NaN        NaN     NaN
# 2293             Lu Valente ♥︎   NaN  ...    NaN        NaN     NaN
# 2294    Marcus Vinicius 🇧🇷🇺🇸🇺🇦   NaN  ...    NaN        NaN     NaN
#
#      retweet_id                                           reply_to  \
# 0           NaN                                                 []
# 1           NaN                                                 []
# 2           NaN                                                 []
# 3           NaN                                                 []
# 4           NaN                                                 []
# ...         ...                                                ...
# 2290        NaN  [{'screen_name': 'magazineluiza', 'name': 'Lu ...
# 2291        NaN                                                 []
# 2292        NaN  [{'screen_name': 'jhopxart', 'name': "burn⁷; h...
# 2293        NaN  [{'screen_name': 'colaressluisa', 'name': 'luí...
# 2294        NaN                                                 []
#
#       retweet_date  translate  trans_src trans_dest cluster
# 0              NaN        NaN        NaN        NaN       1
# 1              NaN        NaN        NaN        NaN       1
# 2              NaN        NaN        NaN        NaN       1
# 3              NaN        NaN        NaN        NaN       7
# 4              NaN        NaN        NaN        NaN       1
# ...            ...        ...        ...        ...     ...
# 2290           NaN        NaN        NaN        NaN       5
# 2291           NaN        NaN        NaN        NaN       0
# 2292           NaN        NaN        NaN        NaN       0
# 2293           NaN        NaN        NaN        NaN       5
# 2294           NaN        NaN        NaN        NaN       0
#
# [2295 rows x 37 columns]

# %%
comentarios['cluster'].value_counts(normalize=True)
# Out:
# 5    0.310675
# 0    0.145969
# 1    0.138562
# 2    0.127233
# 7    0.120261
# 3    0.074074
# 6    0.048802
# 4    0.034423
# Name: cluster, dtype: float64

# %%
cluster0 = comentarios[comentarios['cluster']==0]
cluster1 = comentarios[comentarios['cluster']==1]
cluster2 = comentarios[comentarios['cluster']==2]
cluster3 = comentarios[comentarios['cluster']==3]
cluster4 = comentarios[comentarios['cluster']==4]
cluster5 = comentarios[comentarios['cluster']==5]
cluster6 = comentarios[comentarios['cluster']==6]
cluster7 = comentarios[comentarios['cluster']==7]

# %% [markdown]
# Nuvem de plavras Cluster 0

# %%
from wordcloud import WordCloud
long_string = ','.join(list(cluster0['tweet'].values))
wordcloud = WordCloud(background_color="white", max_words=5000, contour_width=3, contour_color='steelblue')
wordcloud.generate(long_string)
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0x7FE2E4027F90>

# %% [markdown]
# Cluster 1

# %%
from wordcloud import WordCloud
long_string = ','.join(list(cluster1['tweet'].values))
wordcloud = WordCloud(background_color="white", max_words=5000, contour_width=3, contour_color='steelblue')
wordcloud.generate(long_string)
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0x7FE2EE658290>

# %% [markdown]
# Cluster 2

# %%
from wordcloud import WordCloud
long_string = ','.join(list(cluster2['tweet'].values))
wordcloud = WordCloud(background_color="white", max_words=5000, contour_width=3, contour_color='steelblue')
wordcloud.generate(long_string)
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0x7FE2E434D710>

# %% [markdown]
# Cluster 3

# %%
from wordcloud import WordCloud
long_string = ','.join(list(cluster3['tweet'].values))
wordcloud = WordCloud(background_color="white", max_words=5000, contour_width=3, contour_color='steelblue')
wordcloud.generate(long_string)
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0x7FE2E4153D10>

# %% [markdown]
# Cluster 4

# %%
from wordcloud import WordCloud
long_string = ','.join(list(cluster4['tweet'].values))
wordcloud = WordCloud(background_color="white", max_words=5000, contour_width=3, contour_color='steelblue')
wordcloud.generate(long_string)
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0x7FE2E3C59AD0>

# %% [markdown]
# Cluster 5

# %%
from wordcloud import WordCloud
long_string = ','.join(list(cluster5['tweet'].values))
wordcloud = WordCloud(background_color="white", max_words=5000, contour_width=3, contour_color='steelblue')
wordcloud.generate(long_string)
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0x7FE2E6A15850>

# %% [markdown]
# Cluster 6

# %%
from wordcloud import WordCloud
long_string = ','.join(list(cluster6['tweet'].values))
wordcloud = WordCloud(background_color="white", max_words=5000, contour_width=3, contour_color='steelblue')
wordcloud.generate(long_string)
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0x7FE2E41CFD10>

# %% [markdown]
# Cluster 7

# %%
from wordcloud import WordCloud
long_string = ','.join(list(cluster7['tweet'].values))
wordcloud = WordCloud(background_color="white", max_words=5000, contour_width=3, contour_color='steelblue')
wordcloud.generate(long_string)
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0x7FE2E3FE9990>
