# %%
# !pip install nltk
# !pip install gensim

# %%
#importação de bibliotecas
import nltk
import urllib
import bs4 as bs
import re 
from gensim.models  import Word2Vec
import pandas as pd
import numpy as np

# %%
#download nltk

nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopword')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Fabio\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Fabio\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Error loading stopword: Package 'stopword' not found in
# [nltk_data]     index
# False

# %%
#importar base de dados 

comentarios = pd.read_csv("./magalu_2022_n/tweets.csv", delimiter = ",", encoding='UTF-8')

# %%
comentarios['tweet']
# Out:
# 0       Churrasqueira a Carvão Portátil com Ventilador...
# 1       [Magazine Luiza] Xbox Series S 2020 Nova Geraç...
# 2       @magazineluiza tô querendo comprar uma mesa pa...
# 3       @magazineluiza Consegue aquele cupom de descon...
# 4                              @magazineluiza Respondi lá
#                               ...
# 1867    @magazineluiza Pois é, por isso mesmo fiquei d...
# 1868    ⚠️ Alerta de oferta - Magazine Luiza 🗣️  ↪️ Li...
# 1869    @magazineluiza @Anitta Dá um cupom pra mim magalu
# 1870                           @magazineluiza Desconto100
# 1871    @magazineluiza legal, né? pra vender e cobrar ...
# Name: tweet, Length: 1872, dtype: object

# %%
comentarios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1872 entries, 0 to 1871
# Data columns (total 36 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               1872 non-null   int64
#  1   conversation_id  1872 non-null   int64
#  2   created_at       1872 non-null   object
#  3   date             1872 non-null   object
#  4   time             1872 non-null   object
#  5   timezone         1872 non-null   int64
#  6   user_id          1872 non-null   int64
#  7   username         1872 non-null   object
#  8   name             1872 non-null   object
#  9   place            3 non-null      object
#  10  tweet            1872 non-null   object
#  11  language         1872 non-null   object
#  12  mentions         1872 non-null   object
#  13  urls             1872 non-null   object
#  14  photos           1872 non-null   object
#  15  replies_count    1872 non-null   int64
#  16  retweets_count   1872 non-null   int64
# ...

# %%
nltk.download("webtext")
# Out:
# [nltk_data] Downloading package webtext to
# [nltk_data]     C:\Users\Fabio\AppData\Roaming\nltk_data...
# [nltk_data]   Package webtext is already up-to-date!
# True

# %%
#transformar a coluna manifestação em uma lista 

col_one_list = comentarios['tweet'].tolist()
texto = str(col_one_list)

# %%
texto
# Out:
# '[\'Churrasqueira a Carvão Portátil com Ventilador - Nell GB-PC1 PR com Assadeira (cód. magazineluiza 228864300) Vendido e entregue por Magalu de  R$ 423,58 por R$ 370,00  ou em 8x de R$ 46,25 sem juros Comprar:  https://t.co/iNJFTu2RI9?  https://t.co/FaFyakRu1R\', \'[Magazine Luiza] Xbox Series S 2020 Nova Geração 512GB SSD- 1 Controle Branco Microsoft R$ 2229,00 #desconto #oferta #promocao #xbox  https://t.co/pyV1cxaUiK\', \'@magazineluiza tô querendo comprar uma mesa para escritório, mas preciso de um cupom de desconto, cadê ? \\U0001f979\\U0001f979\', \'@magazineluiza Consegue aquele cupom de desconto maravilhoso pra comprar essa maravilha com vcs?  https://t.co/3CL5qspSHp\', \'@magazineluiza Respondi lá\', \'Torneira para Cozinha Gourmet de Mesa Dupla Nell - F-02 CRO Prata (cód. magazineluiza 231138700) Vendido e entregue por Magalu de  R$ 524,99 por R$ 400,00  ou em 8x de R$ 50,00 sem juros Comprar:  https://t.co/yEClMDvIaJ?  https://t.co/HjtGV1eDdr\', \'@magazineluiza chama o 
# ...

# %%
# !pip install demoji

# %%
#Removendo emoji do texto
texto = demoji.replace(texto,"")
texto
len(demoji.findall(texto))
# Out:
# 0

# %%
#converter lista para texto 
moby_tokens = nltk.word_tokenize(texto)
text1 = nltk.Text(moby_tokens)
text1
# Out:
# <Text: [ 'Churrasqueira a Carvão Portátil com Ventilador -...>

# %%
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\Fabio\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
#total de termos no documento
from nltk.stem import WordNetLemmatizer

def total_termos():

    lemmatizer = WordNetLemmatizer()
    lemmatized = [lemmatizer.lemmatize(w,'v') for w in text1]

    return len(set(lemmatized))

total_termos()
# Out:
# 7425

# %%
#importar bibliotecas bigram e trigam
from nltk.collocations import BigramCollocationFinder
from nltk.collocations import TrigramCollocationFinder
from nltk.metrics import BigramAssocMeasures
from nltk.metrics import TrigramAssocMeasures
from nltk.corpus import stopwords

# %%
#encontrar bigrams por token 

procurar = BigramCollocationFinder.from_words(moby_tokens)

# %%
#encontrar trigram por token 

procurar2 = TrigramCollocationFinder.from_words(moby_tokens)

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Fabio\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
#retira stopwords
retira = set(stopwords.words('portuguese'))
#retira

# %%
#filtro para retirar as stopwords e palavras com menos de 3 caracteres
filtra = lambda w: len(w) <3 or w in retira

# %%
procurar.apply_word_filter(filtra)
procurar2.apply_word_filter(filtra)

# %%
#bigram 
procurar.nbest(BigramAssocMeasures.likelihood_ratio, 60)
# Out:
# [('Magazine', 'Luiza'),
#  ('magazine', 'luiza'),
#  ('magazine', 'Luiza'),
#  ('Nova', 'Geração'),
#  ("'Oferta", 'Magazine'),
#  ('2020', 'Nova'),
#  ('MAGAZINE', 'LUIZA'),
#  ('algumas', 'regiões'),
#  ('FRETE', 'GRÁTIS'),
#  ('Gabriel', 'Monteiro'),
#  ("'Magazine", 'Luiza'),
#  ('Xbox', 'Series'),
#  ('Aragão', 'Pinterest'),
#  ('Força', 'Gio'),
#  ('Gio', 'Renato'),
#  ('Pinterest', 'Pfizer'),
#  ('Renato', 'Aragão'),
#  ('Controle', 'Branco'),
#  ('1TB', 'SSD'),
#  ('nota', 'fiscal'),
#  ('Branco', 'Sony'),
#  ('época', 'cosméticos'),
#  ('tudo', 'bem'),
#  ('Geração', '1TB'),
#  ('Geração', '825GB'),
#  ("'EBS", 'Propaganda'),
#  ('criança', 'vulnerável'),
#  ('Sony', 'Retornou'),
#  ('CEP', 'https'),
#  ('dias', 'úteis'),
#  ('alguma', 'coisa'),
#  ('Controle', 'Preto'),
#  ('frete', 'grátis'),
#  ('pra', 'mim'),
#  ('São', 'Paulo'),
#  ('diz', 'CEO'),
#  ('Menor', 'preço'),
#  ('GRÁTIS', 'Vendido'),
#  ("'Xbox", 'Series'),
#  ('documentos', 'referentes'),
# ...

# %%
#Fazendo tokenização e retirada de stopwords do texto completo
from nltk.util import ngrams
token=nltk.word_tokenize(texto)
tokens1 = [word for word in token if word not in retira] 
#tokens1
#from string import punctuation
#token=nltk.word_tokenize(text)
#bigrams=ngrams(token,2)

# %%
#retirando pontuação e separadores
from string import punctuation
tokens1 = [word for word in tokens1 if word not in punctuation]
tokens1
# Out:
# ["'Churrasqueira",
#  'Carvão',
#  'Portátil',
#  'Ventilador',
#  'Nell',
#  'GB-PC1',
#  'PR',
#  'Assadeira',
#  'cód',
#  'magazineluiza',
#  '228864300',
#  'Vendido',
#  'entregue',
#  'Magalu',
#  'R',
#  '423,58',
#  'R',
#  '370,00',
#  '8x',
#  'R',
#  '46,25',
#  'juros',
#  'Comprar',
#  'https',
#  '//t.co/iNJFTu2RI9',
#  'https',
#  '//t.co/FaFyakRu1R',
#  'Magazine',
#  'Luiza',
#  'Xbox',
#  'Series',
#  'S',
#  '2020',
#  'Nova',
#  'Geração',
#  '512GB',
#  'SSD-',
#  '1',
#  'Controle',
#  'Branco',
#  'Microsoft',
#  'R',
#  '2229,00',
#  'desconto',
#  'oferta',
#  'promocao',
#  'xbox',
#  'https',
#  '//t.co/pyV1cxaUiK',
#  'magazineluiza',
#  'tô',
#  'querendo',
#  'comprar',
#  'mesa',
#  'escritório',
#  'preciso',
#  'cupom',
#  'desconto',
#  'cadê',
#  '\\U0001f979\\U0001f979',
#  'magazineluiza',
#  'Consegue',
#  'cupom',
#  'desconto',
#  'maravilhoso',
#  'pra',
#  'comprar',
#  'maravilha',
#  'vcs',
#  'https',
#  '//t.co/3CL5qspSHp',
# ...

# %%
n_grams1 = ngrams(tokens1, 2)
n_grams1 = [ ' '.join(grams) for grams in n_grams1]
#n_grams1
#print(f'N-Gram using NLTK (n = 2): \n{tokens1} => {n_grams1}')

# %%
## Mostrando os Trigrans com a ngrams
from nltk.util import ngrams
#bigrams=ngrams(tokens1,2)
#bigrams
trigrans = ngrams(tokens1, 3)

trig_t10 = []
for grams in trigrans:
    #print(list(grams))
    trig_t10.append(list(grams))
trig_t10[0:10]
# Out:
# [["'Churrasqueira", 'a', 'Carvão'],
#  ['a', 'Carvão', 'Portátil'],
#  ['Carvão', 'Portátil', 'com'],
#  ['Portátil', 'com', 'Ventilador'],
#  ['com', 'Ventilador', 'Nell'],
#  ['Ventilador', 'Nell', 'GB-PC1'],
#  ['Nell', 'GB-PC1', 'PR'],
#  ['GB-PC1', 'PR', 'com'],
#  ['PR', 'com', 'Assadeira'],
#  ['com', 'Assadeira', 'cód']]

# %%
#Top 10 Quadrigrans
quad = ngrams(tokens1, 4)

quad_t10 = []
for grams in quad:
    #print(list(grams))
    quad_t10.append(list(grams))
quad_t10[0:10]
# Out:
# [["'Churrasqueira", 'a', 'Carvão', 'Portátil'],
#  ['a', 'Carvão', 'Portátil', 'com'],
#  ['Carvão', 'Portátil', 'com', 'Ventilador'],
#  ['Portátil', 'com', 'Ventilador', 'Nell'],
#  ['com', 'Ventilador', 'Nell', 'GB-PC1'],
#  ['Ventilador', 'Nell', 'GB-PC1', 'PR'],
#  ['Nell', 'GB-PC1', 'PR', 'com'],
#  ['GB-PC1', 'PR', 'com', 'Assadeira'],
#  ['PR', 'com', 'Assadeira', 'cód'],
#  ['com', 'Assadeira', 'cód', 'magazineluiza']]

# %%
#Top 10 Sixgram
six = ngrams(tokens1, 6)

six_t10 = []
for grams in six:
    #print(list(grams))
    six_t10.append(list(grams))
six_t10[0:10]
# Out:
# [["'Churrasqueira", 'a', 'Carvão', 'Portátil', 'com', 'Ventilador'],
#  ['a', 'Carvão', 'Portátil', 'com', 'Ventilador', 'Nell'],
#  ['Carvão', 'Portátil', 'com', 'Ventilador', 'Nell', 'GB-PC1'],
#  ['Portátil', 'com', 'Ventilador', 'Nell', 'GB-PC1', 'PR'],
#  ['com', 'Ventilador', 'Nell', 'GB-PC1', 'PR', 'com'],
#  ['Ventilador', 'Nell', 'GB-PC1', 'PR', 'com', 'Assadeira'],
#  ['Nell', 'GB-PC1', 'PR', 'com', 'Assadeira', 'cód'],
#  ['GB-PC1', 'PR', 'com', 'Assadeira', 'cód', 'magazineluiza'],
#  ['PR', 'com', 'Assadeira', 'cód', 'magazineluiza', '228864300'],
#  ['com', 'Assadeira', 'cód', 'magazineluiza', '228864300', 'Vendido']]

# %%
#quais são os termos mais frequentes 
def termos_frequentes():
  dist = nltk.FreqDist(text1)
  vocab1= dist.keys()
  freqwords = [w for w in vocab1 if len(w) > 3 and dist[w] >2]
  return sorted(freqwords)
termos_frequentes()
# Out:
# ["'Acabou",
#  "'Box",
#  "'Como",
#  "'Comprei",
#  "'EBS",
#  "'Fiz",
#  "'Gente",
#  "'Kit",
#  "'Magazine",
#  "'Nossa",
#  "'Nunca",
#  "'Não",
#  "'Oferta",
#  "'Ola",
#  "'PS5",
#  "'PlayStation",
#  "'Que",
#  "'Queda",
#  "'Tem",
#  "'Xbox",
#  "'alô",
#  "'comprei",
#  "'gente",
#  "'magazine",
#  "'meu",
#  "'nossa",
#  "'não",
#  "'que",
#  '....',
#  '//t.co/0ckNslhMYl',
#  '//t.co/8vrFpgBrNq',
#  '//t.co/VEK17OKO9X',
#  '//t.co/w4DQWn8rwQ',
#  '//t.co/ycTuk9SFle',
#  '0800',
#  '08bits',
#  '09:33',
#  '2020',
#  '2022',
#  '28.3',
#  '287,88',
#  '59,90',
#  '69,90',
#  '825GB',
#  '911Literatura',
#  'AGORA',
#  'AMER3',
#  'Acho',
#  'Acreditamos',
#  'Acredito',
#  'Agora',
#  'Ainda',
#  'Ajuda',
#  'Alerta',
#  'Amazon',
#  'Americanas',
#  'Anitta',
#  'Aqui',
#  'Aragão',
#  'Assim',
#  'BRAP4',
#  'Bandido',
#  'Black',
#  'Bolsonaro',
#  'Bonecos',
#  'Bora',
#  'Bradespar',
#  'Branco',
#  'Brasil',
#  'BuserBrasil',
#  'COMPRA',
#  'COMPRAR',
#  'CYRE3',
# ...

# %%
dist = nltk.FreqDist(text1)
vocab1 = dist.keys()
freqwords = [w for w in vocab1 if len(w) > 3 and dist[w] >2]
total = str(freqwords)

# %%
# !pip install WordCloud

# %%
#wordcloud 
from wordcloud import WordCloud
import matplotlib.pyplot as plt

wordcloud = WordCloud(max_font_size=100, width=1520, height=535).generate(total)
plt.figure(figsize=(16,9))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %% [markdown]
# Cluster

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import normalize
from sklearn.cluster import KMeans
from sklearn.metrics.pairwise import cosine_similarity

# %%
import seaborn as sns
import matplotlib as mtl
import matplotlib.pyplot as plt

# %%
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(comentarios["tweet"])

# %%
X = normalize(X)

# %%
# Cria a Curva de Cotovelo para encontrar o Numero Ideal de Clusters
from sklearn.cluster import KMeans
wcss = []

for i in range(2, 10):
    kmeans = KMeans(n_clusters = i, max_iter = 300, n_init = 10, random_state = 0)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
    
# Mostra o Gráfico
plt.plot(range(2, 10), wcss)
plt.title('CThe Elbow Method')
plt.xlabel('Numero de Clusters')
plt.ylabel('WCSS') #within cluster sum of squares
plt.show()
plt.savefig('elbow.png', format='png')

# %%
# vamos usar o n de cluster recomendado pelo metodo elbow n=6
kmeans = KMeans(
    n_clusters=6,
    n_init=15,
    max_iter=450,
    init = 'k-means++'
    
)

# %%
#treinar 

kmeans.fit(X)
# Out:
# KMeans(max_iter=450, n_clusters=6, n_init=15)

# %%
comentarios['cluster'] = kmeans.labels_
comentarios
# Out:
#                        id      conversation_id  \
# 0     1509681451796774915  1509681451796774915
# 1     1509680716900098056  1509680716900098056
# 2     1509679781478113283  1509679781478113283
# 3     1509678913571758083  1509678913571758083
# 4     1509674281797623822  1509591357597306890
# ...                   ...                  ...
# 1867  1507761408590684166  1507745516645462027
# 1868  1507761065018507273  1507761065018507273
# 1869  1507761060819918851  1507324766394454020
# 1870  1507760949213732870  1507720627129659395
# 1871  1507759736812412936  1507759736812412936
#
#                                       created_at        date      time  \
# 0     2022-03-31 20:58:01 Hora oficial do Brasil  2022-03-31  20:58:01
# 1     2022-03-31 20:55:06 Hora oficial do Brasil  2022-03-31  20:55:06
# 2     2022-03-31 20:51:23 Hora oficial do Brasil  2022-03-31  20:51:23
# 3     2022-03-31 20:47:56 Hora oficial do Brasil  2022-03-31  20:47:56
# ...

# %%
comentarios['cluster'].value_counts(normalize=True)
# Out:
# 4    0.393697
# 0    0.208868
# 5    0.130876
# 2    0.130342
# 3    0.090278
# 1    0.045940
# Name: cluster, dtype: float64

# %%
cluster0 = comentarios[comentarios['cluster']==0]
cluster1 = comentarios[comentarios['cluster']==1]
cluster2 = comentarios[comentarios['cluster']==2]
cluster3 = comentarios[comentarios['cluster']==3]
cluster4 = comentarios[comentarios['cluster']==4]
cluster5 = comentarios[comentarios['cluster']==5]

# %% [markdown]
# Nuvem de plavras Cluster 0

# %%
from wordcloud import WordCloud
long_string = ','.join(list(cluster0['tweet'].values))
wordcloud = WordCloud(background_color="white", max_words=5000, contour_width=3, contour_color='steelblue')
wordcloud.generate(long_string)
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0x1AE5134EF10>

# %% [markdown]
# Cluster 1

# %%
from wordcloud import WordCloud
long_string = ','.join(list(cluster1['tweet'].values))
wordcloud = WordCloud(background_color="white", max_words=5000, contour_width=3, contour_color='steelblue')
wordcloud.generate(long_string)
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0x1AE56AA4B80>

# %% [markdown]
# Cluster 2

# %%
from wordcloud import WordCloud
long_string = ','.join(list(cluster2['tweet'].values))
wordcloud = WordCloud(background_color="white", max_words=5000, contour_width=3, contour_color='steelblue')
wordcloud.generate(long_string)
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0x1AE56A8C280>

# %% [markdown]
# Cluster 3

# %%
from wordcloud import WordCloud
long_string = ','.join(list(cluster3['tweet'].values))
wordcloud = WordCloud(background_color="white", max_words=5000, contour_width=3, contour_color='steelblue')
wordcloud.generate(long_string)
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0x1AE56ACC070>

# %% [markdown]
# Cluster 4

# %%
from wordcloud import WordCloud
long_string = ','.join(list(cluster4['tweet'].values))
wordcloud = WordCloud(background_color="white", max_words=5000, contour_width=3, contour_color='steelblue')
wordcloud.generate(long_string)
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0x1AE56AD08B0>

# %% [markdown]
# Cluster 5

# %%
from wordcloud import WordCloud
long_string = ','.join(list(cluster5['tweet'].values))
wordcloud = WordCloud(background_color="white", max_words=5000, contour_width=3, contour_color='steelblue')
wordcloud.generate(long_string)
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0x1AE4ED17760>

# %%
text = str(cluster0['tweet'].tolist())
text = demoji.replace(text,"")
tk = nltk.word_tokenize(text)
tk = [w for w in tk if not w in set(stopwords.words('portuguese'))]
tk = [w for w in tk if not w in punctuation]
len(tk)
# Out:
# 7158

# %%
# Função para limpar e tokenizar os clusters
def clear_text_cluster(vet):
    from string import punctuation
    
    text = str(vet.tolist())
    text = demoji.replace(text,"")
    text = text.replace('\\U0001f979',"")
    text = text.replace('\\u200d',"")
    tk = nltk.word_tokenize(text)
    tk = [w for w in tk if not w in set(stopwords.words('portuguese'))]
    tk = [w for w in tk if not w in punctuation]
    
    return tk

# Função para mostrar os ngrams
def view_ngrams(token,n):
    r_gram = ngrams(token,n)
    r_top = []
    for grams in r_gram:
        r_top.append(list(grams))
    return r_top

# %%
tk_cl0 = clear_text_cluster(cluster0['tweet'])

# %% [markdown]
# ### Verificando o Cluster 0

# %%
# Trigrams
view_ngrams(tk_cl0,3)[0:20]
# Out:
# [['magazineluiza', 'tô', 'querendo'],
#  ['tô', 'querendo', 'comprar'],
#  ['querendo', 'comprar', 'mesa'],
#  ['comprar', 'mesa', 'escritório'],
#  ['mesa', 'escritório', 'preciso'],
#  ['escritório', 'preciso', 'cupom'],
#  ['preciso', 'cupom', 'desconto'],
#  ['cupom', 'desconto', 'cadê'],
#  ['desconto', 'cadê', 'aquieujazz'],
#  ['cadê', 'aquieujazz', 'magazineluiza'],
#  ['aquieujazz', 'magazineluiza', 'cmg'],
#  ['magazineluiza', 'cmg', 'tá'],
#  ['cmg', 'tá', 'msm'],
#  ['tá', 'msm', 'jeito'],
#  ['msm', 'jeito', 'tá'],
#  ['jeito', 'tá', 'atrasado'],
#  ['tá', 'atrasado', 'desde'],
#  ['atrasado', 'desde', '15/03'],
#  ['desde', '15/03', 'liguei'],
#  ['15/03', 'liguei', 'liguei']]

# %%
# sixgrams
view_ngrams(tk_cl0,6)[0:20]
# Out:
# [['magazineluiza', 'tô', 'querendo', 'comprar', 'mesa', 'escritório'],
#  ['tô', 'querendo', 'comprar', 'mesa', 'escritório', 'preciso'],
#  ['querendo', 'comprar', 'mesa', 'escritório', 'preciso', 'cupom'],
#  ['comprar', 'mesa', 'escritório', 'preciso', 'cupom', 'desconto'],
#  ['mesa', 'escritório', 'preciso', 'cupom', 'desconto', 'cadê'],
#  ['escritório', 'preciso', 'cupom', 'desconto', 'cadê', 'aquieujazz'],
#  ['preciso', 'cupom', 'desconto', 'cadê', 'aquieujazz', 'magazineluiza'],
#  ['cupom', 'desconto', 'cadê', 'aquieujazz', 'magazineluiza', 'cmg'],
#  ['desconto', 'cadê', 'aquieujazz', 'magazineluiza', 'cmg', 'tá'],
#  ['cadê', 'aquieujazz', 'magazineluiza', 'cmg', 'tá', 'msm'],
#  ['aquieujazz', 'magazineluiza', 'cmg', 'tá', 'msm', 'jeito'],
#  ['magazineluiza', 'cmg', 'tá', 'msm', 'jeito', 'tá'],
#  ['cmg', 'tá', 'msm', 'jeito', 'tá', 'atrasado'],
#  ['tá', 'msm', 'jeito', 'tá', 'atrasado', 'desde'],
#  ['msm', 'jeito', 'tá', 'atrasado', 'desde', '15/03'],
# ...

# %% [markdown]
# ### Verificando o Cluster 1

# %%
tk_cl1 = clear_text_cluster(cluster1['tweet'])

# Trigrams
view_ngrams(tk_cl1,3)[0:20]
# Out:
# [['slpng_giants_pt', 'magazineluiza', 'YouTubeBrasil'],
#  ['magazineluiza', 'YouTubeBrasil', 'slpng_giants_pt'],
#  ['YouTubeBrasil', 'slpng_giants_pt', 'magazineluiza'],
#  ['slpng_giants_pt', 'magazineluiza', 'YouTubeBrasil'],
#  ['magazineluiza', 'YouTubeBrasil', 'magazineluiza'],
#  ['YouTubeBrasil', 'magazineluiza', 'DesmonetizaGabrielMonteiro'],
#  ['magazineluiza', 'DesmonetizaGabrielMonteiro', 'mínimo'],
#  ['DesmonetizaGabrielMonteiro', 'mínimo', 'empresa'],
#  ['mínimo', 'empresa', 'cidadã'],
#  ['empresa', 'cidadã', 'slpng_giants_pt'],
#  ['cidadã', 'slpng_giants_pt', 'magazineluiza'],
#  ['slpng_giants_pt', 'magazineluiza', 'YouTubeBrasil'],
#  ['magazineluiza', 'YouTubeBrasil', 'DesmonetizaGabrielMonteiro'],
#  ['YouTubeBrasil', 'DesmonetizaGabrielMonteiro', 'slpng_giants_pt'],
#  ['DesmonetizaGabrielMonteiro', 'slpng_giants_pt', 'magazineluiza'],
#  ['slpng_giants_pt', 'magazineluiza', 'YouTubeBrasil'],
#  ['magazineluiza', 'YouTubeBrasil', 'magazineluiza'],
# ...

# %% [markdown]
# ### Verificando Cluster 2

# %%
tk_cl2 = clear_text_cluster(cluster2['tweet'])

# Sixgram
view_ngrams(tk_cl2,6)[0:20]
# Out:
# [["'Churrasqueira", 'Carvão', 'Portátil', 'Ventilador', 'Nell', 'GB-PC1'],
#  ['Carvão', 'Portátil', 'Ventilador', 'Nell', 'GB-PC1', 'PR'],
#  ['Portátil', 'Ventilador', 'Nell', 'GB-PC1', 'PR', 'Assadeira'],
#  ['Ventilador', 'Nell', 'GB-PC1', 'PR', 'Assadeira', 'cód'],
#  ['Nell', 'GB-PC1', 'PR', 'Assadeira', 'cód', 'magazineluiza'],
#  ['GB-PC1', 'PR', 'Assadeira', 'cód', 'magazineluiza', '228864300'],
#  ['PR', 'Assadeira', 'cód', 'magazineluiza', '228864300', 'Vendido'],
#  ['Assadeira', 'cód', 'magazineluiza', '228864300', 'Vendido', 'entregue'],
#  ['cód', 'magazineluiza', '228864300', 'Vendido', 'entregue', 'Magalu'],
#  ['magazineluiza', '228864300', 'Vendido', 'entregue', 'Magalu', 'R'],
#  ['228864300', 'Vendido', 'entregue', 'Magalu', 'R', '423,58'],
#  ['Vendido', 'entregue', 'Magalu', 'R', '423,58', 'R'],
#  ['entregue', 'Magalu', 'R', '423,58', 'R', '370,00'],
#  ['Magalu', 'R', '423,58', 'R', '370,00', '8x'],
#  ['R', '423,58', 'R', '370,00', '8x', 'R'],
# ...

# %% [markdown]
# ### Verificando Cluster 3

# %%
tk_cl3 = clear_text_cluster(cluster3['tweet'])

# Sixgram
view_ngrams(tk_cl3,6)[0:20]
# Out:
# [["'ninguém", 'tira', 'cabeça', 'Lu', 'magazineluiza', 'Anitta'],
#  ['tira', 'cabeça', 'Lu', 'magazineluiza', 'Anitta', 'VersionsOfMe'],
#  ['cabeça', 'Lu', 'magazineluiza', 'Anitta', 'VersionsOfMe', 'https'],
#  ['Lu',
#   'magazineluiza',
#   'Anitta',
#   'VersionsOfMe',
#   'https',
#   '//t.co/xjr1vXISbT'],
#  ['magazineluiza',
#   'Anitta',
#   'VersionsOfMe',
#   'https',
#   '//t.co/xjr1vXISbT',
#   'Anitta'],
#  ['Anitta',
#   'VersionsOfMe',
#   'https',
#   '//t.co/xjr1vXISbT',
#   'Anitta',
#   'magazineluiza'],
#  ['VersionsOfMe',
#   'https',
#   '//t.co/xjr1vXISbT',
#   'Anitta',
#   'magazineluiza',
#   'capa'],
#  ['https', '//t.co/xjr1vXISbT', 'Anitta', 'magazineluiza', 'capa', 'Anitta'],
#  ['//t.co/xjr1vXISbT', 'Anitta', 'magazineluiza', 'capa', 'Anitta', 'https'],
#  ['Anitta', 'magazineluiza', 'capa', 'Anitta', 'https', '//t.co/xfv6zS4See'],
#  ['magazineluiza', 'capa', 'Anitta', 'https', '//t.co/xfv6zS4See', '_haviz_'],
# ...

# %% [markdown]
# ### Verificando Cluster 4

# %%
tk_cl4 = clear_text_cluster(cluster4['tweet'])

# Sixgram
view_ngrams(tk_cl4,6)[120:140]
# Out:
# [['ReclameAQUI', 'Oi', 'Sentimos', 'Envia', 'direct', 'gente'],
#  ['Oi', 'Sentimos', 'Envia', 'direct', 'gente', 'explicando'],
#  ['Sentimos', 'Envia', 'direct', 'gente', 'explicando', 'aconteceu'],
#  ['Envia', 'direct', 'gente', 'explicando', 'aconteceu', 'favor'],
#  ['direct', 'gente', 'explicando', 'aconteceu', 'favor', 'Vamos'],
#  ['gente', 'explicando', 'aconteceu', 'favor', 'Vamos', 'ajudar'],
#  ['explicando', 'aconteceu', 'favor', 'Vamos', 'ajudar', 'lá'],
#  ['aconteceu', 'favor', 'Vamos', 'ajudar', 'lá', 'MeliuzOficial'],
#  ['favor', 'Vamos', 'ajudar', 'lá', 'MeliuzOficial', 'magazineluiza'],
#  ['Vamos', 'ajudar', 'lá', 'MeliuzOficial', 'magazineluiza', 'Pra'],
#  ['ajudar', 'lá', 'MeliuzOficial', 'magazineluiza', 'Pra', 'ter'],
#  ['lá', 'MeliuzOficial', 'magazineluiza', 'Pra', 'ter', 'feito'],
#  ['MeliuzOficial', 'magazineluiza', 'Pra', 'ter', 'feito', 'tudo'],
#  ['magazineluiza', 'Pra', 'ter', 'feito', 'tudo', 'certinho'],
# ...

# %% [markdown]
# ### Verificando Cluster 5

# %%
tk_cl5 = clear_text_cluster(cluster5['tweet'])

# Sixgram
view_ngrams(tk_cl5,6)[160:180]
# Out:
# [['q', 'apostaram', 'hipocrisia', 'politicamente', 'correto.A', 'sociedade'],
#  ['apostaram',
#   'hipocrisia',
#   'politicamente',
#   'correto.A',
#   'sociedade',
#   'calada'],
#  ['hipocrisia', 'politicamente', 'correto.A', 'sociedade', 'calada', 'olhos'],
#  ['politicamente', 'correto.A', 'sociedade', 'calada', 'olhos', 'abertos'],
#  ['correto.A', 'sociedade', 'calada', 'olhos', 'abertos', 'Caetanobc'],
#  ['sociedade', 'calada', 'olhos', 'abertos', 'Caetanobc', 'A'],
#  ['calada', 'olhos', 'abertos', 'Caetanobc', 'A', 'MAGAZINE'],
#  ['olhos', 'abertos', 'Caetanobc', 'A', 'MAGAZINE', 'LUIZA'],
#  ['abertos', 'Caetanobc', 'A', 'MAGAZINE', 'LUIZA', 'KKKKKKKK'],
#  ['Caetanobc', 'A', 'MAGAZINE', 'LUIZA', 'KKKKKKKK', 'DressaSamela'],
#  ['A', 'MAGAZINE', 'LUIZA', 'KKKKKKKK', 'DressaSamela', 'magazine'],
#  ['MAGAZINE', 'LUIZA', 'KKKKKKKK', 'DressaSamela', 'magazine', 'luiza'],
#  ['LUIZA', 'KKKKKKKK', 'DressaSamela', 'magazine', 'luiza', 'amiga'],
# ...
